# %% [markdown]
# # Step1 安装依赖

# %%
# !pip uninstall -y parl  # 说明：AIStudio预装的parl版本太老，容易跟其他库产生兼容性冲突，建议先卸载
# !pip uninstall -y pandas scikit-learn # 提示：在AIStudio中卸载这两个库再import parl可避免warning提示，不卸载也不影响parl的使用

# !pip install gym
# !pip install atari-py # 玩Gym的Atari游戏必装依赖，本次作业使用了Atari的Pong(乒乓球)环境
# !pip install paddlepaddle==1.6.3
# !pip install parl==1.3.1

# 说明：安装日志中出现两条红色的关于 paddlehub 和 visualdl 的 ERROR 与parl无关，可以忽略，不影响使用
# Out:
# Uninstalling parl-1.3.1:
#   Successfully uninstalled parl-1.3.1
# WARNING: Skipping pandas as it is not installed.
# WARNING: Skipping scikit-learn as it is not installed.
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple/
# Requirement already satisfied: gym in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: scipy in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from gym) (1.3.0)
# Requirement already satisfied: pyglet>=1.2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from gym) (1.4.5)
# Requirement already satisfied: requests>=2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from gym) (2.22.0)
# Requirement already satisfied: six in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from gym) (1.15.0)
# Requirement already satisfied: numpy>=1.10.4 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from gym) (1.16.4)
# Requirement already satisfied: future in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pyglet>=1.2.0->gym) (0.18.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests>=2.0->gym) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests>=2.0->gym) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests>=2.0->gym) (1.25.6)
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple/
# Requirement already satisfied: atari-py in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (0.2.6)
# Requirement already satisfied: numpy in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from atari-py) (1.16.4)
# Requirement already satisfied: six in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from atari-py) (1.15.0)
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple/
# Collecting parl==1.3.1
#   Using cached https://mirrors.tuna.tsinghua.edu.cn/pypi/web/packages/62/79/590af38a920792c71afb73fad7583967928b4d0ba9fca76250d935c7fda8/parl-1.3.1-py2.py3-none-any.whl
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (1.1.0)
# Requirement already satisfied: flask-cors in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (3.0.8)
# Requirement already satisfied: psutil>=5.6.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (5.7.0)
# Requirement already satisfied: pyarrow==0.13.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (0.13.0)
# Requirement already satisfied: tb-nightly==1.15.0a20190801 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (1.15.0a20190801)
# Requirement already satisfied: flask>=1.0.4 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (1.1.1)
# Requirement already satisfied: click in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (7.0)
# Requirement already satisfied: pyzmq==18.0.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (18.0.1)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (1.3.0)
# Requirement already satisfied: tensorboardX==1.8 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (1.8)
# Requirement already satisfied: cloudpickle==1.2.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (1.2.1)
# Requirement already satisfied: visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux" in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from parl==1.3.1) (2.0.0b6)
# Requirement already satisfied: Six in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flask-cors->parl==1.3.1) (1.15.0)
# Requirement already satisfied: numpy>=1.14 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pyarrow==0.13.0->parl==1.3.1) (1.16.4)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from tb-nightly==1.15.0a20190801->parl==1.3.1) (0.8.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from tb-nightly==1.15.0a20190801->parl==1.3.1) (0.33.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from tb-nightly==1.15.0a20190801->parl==1.3.1) (0.16.0)
# Requirement already satisfied: grpcio>=1.6.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from tb-nightly==1.15.0a20190801->parl==1.3.1) (1.26.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from tb-nightly==1.15.0a20190801->parl==1.3.1) (41.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from tb-nightly==1.15.0a20190801->parl==1.3.1) (3.1.1)
# Requirement already satisfied: protobuf>=3.6.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from tb-nightly==1.15.0a20190801->parl==1.3.1) (3.10.0)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flask>=1.0.4->parl==1.3.1) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flask>=1.0.4->parl==1.3.1) (2.10.3)
# Requirement already satisfied: opencv-python in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (4.1.1.26)
# Requirement already satisfied: Flask-Babel>=1.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (1.0.0)
# Requirement already satisfied: hdfs in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2.5.8)
# Requirement already satisfied: Pillow>=7.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (7.1.2)
# Requirement already satisfied: flake8>=3.7.9 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (3.7.9)
# Requirement already satisfied: pre-commit in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (1.21.0)
# Requirement already satisfied: requests in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask>=1.0.4->parl==1.3.1) (1.1.1)
# Requirement already satisfied: Babel>=2.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Flask-Babel>=1.0.0->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2.8.0)
# Requirement already satisfied: pytz in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Flask-Babel>=1.0.0->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2019.3)
# Requirement already satisfied: docopt in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from hdfs->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (0.6.2)
# Requirement already satisfied: pycodestyle<2.6.0,>=2.5.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2.5.0)
# Requirement already satisfied: pyflakes<2.2.0,>=2.1.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2.1.1)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (0.6.1)
# Requirement already satisfied: entrypoints<0.4.0,>=0.3.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (0.3)
# Requirement already satisfied: virtualenv>=15.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (16.7.9)
# Requirement already satisfied: cfgv>=2.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2.0.1)
# Requirement already satisfied: identify>=1.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (1.4.10)
# Requirement already satisfied: pyyaml in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (5.1.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (0.23)
# Requirement already satisfied: nodeenv>=0.11.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (1.3.4)
# Requirement already satisfied: aspy.yaml in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (1.3.0)
# Requirement already satisfied: toml in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (0.10.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (1.25.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (2.8)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (0.6.0)
# Requirement already satisfied: more-itertools in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->pre-commit->visualdl>=2.0.0b; python_version >= "3" and platform_system == "Linux"->parl==1.3.1) (7.2.0)
# Installing collected packages: parl
# Successfully installed parl-1.3.1

# %%
# 检查依赖包版本是否正确
# !pip list | grep paddlepaddle
# !pip list | grep parl
# Out:
# paddlepaddle         1.6.2
# parl                 1.3.1

# %% [markdown]
# # Step2 导入依赖

# %%
import os
import gym
import numpy as np

import paddle.fluid as fluid
import parl
from parl import layers
from parl.utils import logger

# %% [markdown]
# # Step3 设置超参数

# %%
######################################################################
######################################################################
#
# 1. 请设定 learning rate，尝试增减查看效果
#
######################################################################
######################################################################

LEARNING_RATE = 1e-3

# %% [markdown]
# # Step4 搭建Model、Algorithm、Agent架构
# * `Agent`把产生的数据传给`algorithm`，`algorithm`根据`model`的模型结构计算出`Loss`，使用`SGD`或者其他优化器不断的优化，`PARL`这种架构可以很方便的应用在各类深度强化学习问题中。
#
# #### （1）Model
# `Model`用来定义前向(`Forward`)网络，用户可以自由的定制自己的网络结构。

# %%
class Model(parl.Model):
    def __init__(self, act_dim):
        ######################################################################
        ######################################################################
        self.fc1 = layers.fc(size=400, act='relu')
        self.fc2 = layers.fc(size=act_dim, act='softmax')
        ######################################################################
        ######################################################################

    def forward(self, obs):  # 可直接用 model = Model(5); model(obs)调用
        ######################################################################
        ######################################################################
        h1 = self.fc1(obs)
        out = self.fc2(h1)
        ######################################################################
        ######################################################################
        return out

# %% [markdown]
# #### （2）Algorithm
# * `Algorithm` 定义了具体的算法来更新前向网络(`Model`)，也就是通过定义损失函数来更新`Model`，和算法相关的计算都放在`algorithm`中。

# %%
from parl.algorithms import PolicyGradient # 直接从parl库中导入PolicyGradient算法，无需重复写算法

# %% [markdown]
# #### （3）Agent
# * `Agent`负责算法与环境的交互，在交互过程中把生成的数据提供给`Algorithm`来更新模型(`Model`)，数据的预处理流程也一般定义在这里。

# %%
class Agent(parl.Agent):
    def __init__(self, algorithm, obs_dim, act_dim):
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        super(Agent, self).__init__(algorithm)

    def build_program(self):
        self.pred_program = fluid.Program()
        self.learn_program = fluid.Program()

        with fluid.program_guard(self.pred_program):  # 搭建计算图用于 预测动作，定义输入输出变量
            obs = layers.data(
                name='obs', shape=[self.obs_dim], dtype='float32')
            self.act_prob = self.alg.predict(obs)

        with fluid.program_guard(
                self.learn_program):  # 搭建计算图用于 更新policy网络，定义输入输出变量
            obs = layers.data(
                name='obs', shape=[self.obs_dim], dtype='float32')
            act = layers.data(name='act', shape=[1], dtype='int64')
            reward = layers.data(name='reward', shape=[], dtype='float32')
            self.cost = self.alg.learn(obs, act, reward)

    def sample(self, obs):
        obs = np.expand_dims(obs, axis=0)  # 增加一维维度
        act_prob = self.fluid_executor.run(
            self.pred_program,
            feed={'obs': obs.astype('float32')},
            fetch_list=[self.act_prob])[0]
        act_prob = np.squeeze(act_prob, axis=0)  # 减少一维维度
        act = np.random.choice(range(self.act_dim), p=act_prob)  # 根据动作概率选取动作
        return act

    def predict(self, obs):
        obs = np.expand_dims(obs, axis=0)
        act_prob = self.fluid_executor.run(
            self.pred_program,
            feed={'obs': obs.astype('float32')},
            fetch_list=[self.act_prob])[0]
        act_prob = np.squeeze(act_prob, axis=0)
        act = np.argmax(act_prob)  # 根据动作概率选择概率最高的动作
        return act

    def learn(self, obs, act, reward):
        act = np.expand_dims(act, axis=-1)
        feed = {
            'obs': obs.astype('float32'),
            'act': act.astype('int64'),
            'reward': reward.astype('float32')
        }
        cost = self.fluid_executor.run(
            self.learn_program, feed=feed, fetch_list=[self.cost])[0]
        return cost

# %% [markdown]
# ### Step 5 Training && Test（训练&&测试）

# %%
def run_episode(env, agent):
    obs_list, action_list, reward_list = [], [], []
    obs = env.reset()
    while True:
        obs = preprocess(obs) # from shape (210, 160, 3) to (100800,)
        obs_list.append(obs)
        action = agent.sample(obs) # 采样动作
        action_list.append(action)

        obs, reward, done, info = env.step(action)
        reward_list.append(reward)

        if done:
            break
    return obs_list, action_list, reward_list


# 评估 agent, 跑 5 个episode，求平均
def evaluate(env, agent, render=False):
    eval_reward = []
    for i in range(5):
        obs = env.reset()
        episode_reward = 0
        while True:
            obs = preprocess(obs) # from shape (210, 160, 3) to (100800,)
            action = agent.predict(obs) # 选取最优动作
            obs, reward, isOver, _ = env.step(action)
            episode_reward += reward
            if render:
                env.render()
            if isOver:
                break
        eval_reward.append(episode_reward)
    return np.mean(eval_reward)

# %% [markdown]
# ### Step6 创建环境和Agent，启动训练，保存模型

# %%
# Pong 图片预处理
def preprocess(image):
    """ 预处理 210x160x3 uint8 frame into 6400 (80x80) 1维 float vector """
    image = image[35:195] # 裁剪
    image = image[::2,::2,0] # 下采样，缩放2倍
    image[image == 144] = 0 # 擦除背景 (background type 1)
    image[image == 109] = 0 # 擦除背景 (background type 2)
    image[image != 0] = 1 # 转为灰度图，除了黑色外其他都是白色
    return image.astype(np.float).ravel()


# 根据一个episode的每个step的reward列表，计算每一个Step的Gt
def calc_reward_to_go(reward_list, gamma=0.99):
    """calculate discounted reward"""
    reward_arr = np.array(reward_list)
    for i in range(len(reward_arr) - 2, -1, -1):
        # G_t = r_t + γ·r_t+1 + ... = r_t + γ·G_t+1
        reward_arr[i] += gamma * reward_arr[i + 1]
    # normalize episode rewards
    reward_arr -= np.mean(reward_arr)
    reward_arr /= np.std(reward_arr)
    return reward_arr


# 创建环境
env = gym.make('Pong-v0')
obs_dim = 80 * 80
act_dim = env.action_space.n
logger.info('obs_dim {}, act_dim {}'.format(obs_dim, act_dim))

# 根据parl框架构建agent
######################################################################
######################################################################
#
# 4. 请参考课堂Demo构建 agent，嵌套Model, PolicyGradient, Agent
#
######################################################################
######################################################################
model = Model(act_dim=act_dim)
alg = PolicyGradient(model, lr=LEARNING_RATE)
agent = Agent(alg, obs_dim=obs_dim, act_dim=act_dim)


# 加载模型
# if os.path.exists('./model.ckpt'):
#     agent.restore('./model.ckpt')

for i in range(3000):
    obs_list, action_list, reward_list = run_episode(env, agent)
    if i % 10 == 0:
        logger.info("Train Episode {}, Reward Sum {}.".format(i, 
                                            sum(reward_list)))

    batch_obs = np.array(obs_list)
    batch_action = np.array(action_list)
    batch_reward = calc_reward_to_go(reward_list)

    agent.learn(batch_obs, batch_action, batch_reward)
    if (i + 1) % 100 == 0:
        total_reward = evaluate(env, agent, render=False)
        logger.info('Episode {}, Test reward: {}'.format(i + 1, 
                                            total_reward))

# save the parameters to ./model.ckpt
agent.save('./model.ckpt')
# Out:
# [06-20 03:52:58 MainThread @<ipython-input-8-69d5f0d42f1c>:29] obs_dim 6400, act_dim 6
# [06-20 03:52:58 MainThread @machine_info.py:88] Cannot find available GPU devices, using CPU now.
# [06-20 03:52:58 MainThread @machine_info.py:88] Cannot find available GPU devices, using CPU now.
# [06-20 03:53:03 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 0, Reward Sum -20.0.
# [06-20 03:53:54 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 10, Reward Sum -21.0.
# [06-20 03:54:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 20, Reward Sum -20.0.
# [06-20 03:55:42 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 30, Reward Sum -19.0.
# [06-20 03:56:44 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 40, Reward Sum -18.0.
# [06-20 03:57:40 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 50, Reward Sum -19.0.
# [06-20 03:58:40 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 60, Reward Sum -19.0.
# [06-20 03:59:45 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 70, Reward Sum -20.0.
# [06-20 04:00:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 80, Reward Sum -18.0.
# [06-20 04:02:09 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 90, Reward Sum -19.0.
# [06-20 04:03:42 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 100, Test reward: -19.8
# [06-20 04:03:49 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 100, Reward Sum -18.0.
# [06-20 04:05:12 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 110, Reward Sum -16.0.
# [06-20 04:06:39 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 120, Reward Sum -18.0.
# [06-20 04:08:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 130, Reward Sum -20.0.
# [06-20 04:09:43 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 140, Reward Sum -17.0.
# [06-20 04:11:28 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 150, Reward Sum -17.0.
# [06-20 04:12:57 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 160, Reward Sum -15.0.
# [06-20 04:14:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 170, Reward Sum -15.0.
# [06-20 04:15:55 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 180, Reward Sum -17.0.
# [06-20 04:17:19 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 190, Reward Sum -17.0.
# [06-20 04:19:31 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 200, Test reward: -13.2
# [06-20 04:19:40 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 200, Reward Sum -16.0.
# [06-20 04:21:13 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 210, Reward Sum -13.0.
# [06-20 04:22:46 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 220, Reward Sum -15.0.
# [06-20 04:24:25 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 230, Reward Sum -11.0.
# [06-20 04:26:11 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 240, Reward Sum -16.0.
# [06-20 04:28:01 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 250, Reward Sum -15.0.
# [06-20 04:30:20 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 260, Reward Sum -16.0.
# [06-20 04:32:17 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 270, Reward Sum -11.0.
# [06-20 04:34:17 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 280, Reward Sum -12.0.
# [06-20 04:36:17 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 290, Reward Sum -16.0.
# [06-20 04:39:13 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 300, Test reward: -11.8
# [06-20 04:39:26 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 300, Reward Sum -10.0.
# [06-20 04:41:35 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 310, Reward Sum -13.0.
# [06-20 04:43:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 320, Reward Sum -12.0.
# [06-20 04:46:11 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 330, Reward Sum -14.0.
# [06-20 04:48:28 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 340, Reward Sum -11.0.
# [06-20 04:50:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 350, Reward Sum -13.0.
# [06-20 04:53:11 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 360, Reward Sum -10.0.
# [06-20 04:55:25 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 370, Reward Sum -15.0.
# [06-20 04:57:42 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 380, Reward Sum -7.0.
# [06-20 05:00:00 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 390, Reward Sum -11.0.
# [06-20 05:03:22 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 400, Test reward: -10.0
# [06-20 05:03:34 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 400, Reward Sum -16.0.
# [06-20 05:06:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 410, Reward Sum -2.0.
# [06-20 05:08:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 420, Reward Sum -15.0.
# [06-20 05:10:50 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 430, Reward Sum -15.0.
# [06-20 05:13:25 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 440, Reward Sum -9.0.
# [06-20 05:16:02 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 450, Reward Sum -10.0.
# [06-20 05:18:43 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 460, Reward Sum -15.0.
# [06-20 05:21:08 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 470, Reward Sum -9.0.
# [06-20 05:23:35 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 480, Reward Sum -13.0.
# [06-20 05:26:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 490, Reward Sum -8.0.
# [06-20 05:29:47 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 500, Test reward: -2.8
# [06-20 05:30:04 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 500, Reward Sum -7.0.
# [06-20 05:32:43 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 510, Reward Sum -11.0.
# [06-20 05:35:15 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 520, Reward Sum -6.0.
# [06-20 05:37:57 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 530, Reward Sum -8.0.
# [06-20 05:40:30 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 540, Reward Sum -7.0.
# [06-20 05:42:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 550, Reward Sum -8.0.
# [06-20 05:45:10 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 560, Reward Sum -11.0.
# [06-20 05:47:34 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 570, Reward Sum -8.0.
# [06-20 05:50:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 580, Reward Sum -9.0.
# [06-20 05:52:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 590, Reward Sum -3.0.
# [06-20 05:56:37 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 600, Test reward: -4.6
# [06-20 05:56:54 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 600, Reward Sum -5.0.
# [06-20 05:59:52 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 610, Reward Sum -6.0.
# [06-20 06:02:32 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 620, Reward Sum -12.0.
# [06-20 06:05:28 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 630, Reward Sum -7.0.
# [06-20 06:08:23 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 640, Reward Sum 3.0.
# [06-20 06:11:27 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 650, Reward Sum -8.0.
# [06-20 06:14:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 660, Reward Sum -6.0.
# [06-20 06:16:42 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 670, Reward Sum -1.0.
# [06-20 06:19:10 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 680, Reward Sum -9.0.
# [06-20 06:21:43 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 690, Reward Sum -2.0.
# [06-20 06:25:25 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 700, Test reward: -1.2
# [06-20 06:25:42 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 700, Reward Sum -2.0.
# [06-20 06:28:14 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 710, Reward Sum -6.0.
# [06-20 06:30:49 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 720, Reward Sum -14.0.
# [06-20 06:33:35 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 730, Reward Sum -7.0.
# [06-20 06:36:19 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 740, Reward Sum -6.0.
# [06-20 06:38:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 750, Reward Sum -11.0.
# [06-20 06:41:31 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 760, Reward Sum -2.0.
# [06-20 06:44:12 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 770, Reward Sum -7.0.
# [06-20 06:46:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 780, Reward Sum -7.0.
# [06-20 06:49:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 790, Reward Sum -9.0.
# [06-20 06:52:35 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 800, Test reward: -4.2
# [06-20 06:52:48 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 800, Reward Sum -7.0.
# [06-20 06:55:14 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 810, Reward Sum -8.0.
# [06-20 06:57:46 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 820, Reward Sum -8.0.
# [06-20 07:00:26 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 830, Reward Sum -9.0.
# [06-20 07:03:09 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 840, Reward Sum -7.0.
# [06-20 07:05:36 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 850, Reward Sum -10.0.
# [06-20 07:08:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 860, Reward Sum -8.0.
# [06-20 07:10:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 870, Reward Sum -2.0.
# [06-20 07:13:30 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 880, Reward Sum 3.0.
# [06-20 07:16:13 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 890, Reward Sum -1.0.
# [06-20 07:19:56 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 900, Test reward: -2.2
# [06-20 07:20:10 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 900, Reward Sum 4.0.
# [06-20 07:22:55 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 910, Reward Sum -6.0.
# [06-20 07:26:04 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 920, Reward Sum -1.0.
# [06-20 07:29:10 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 930, Reward Sum -3.0.
# [06-20 07:32:17 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 940, Reward Sum -6.0.
# [06-20 07:35:34 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 950, Reward Sum -3.0.
# [06-20 07:38:49 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 960, Reward Sum -10.0.
# [06-20 07:41:52 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 970, Reward Sum -6.0.
# [06-20 07:44:45 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 980, Reward Sum -3.0.
# [06-20 07:47:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 990, Reward Sum -1.0.
# [06-20 07:52:47 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1000, Test reward: 0.8
# [06-20 07:53:03 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1000, Reward Sum 3.0.
# [06-20 07:55:54 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1010, Reward Sum -3.0.
# [06-20 07:58:45 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1020, Reward Sum -7.0.
# [06-20 08:01:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1030, Reward Sum -3.0.
# [06-20 08:04:53 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1040, Reward Sum -9.0.
# [06-20 08:08:15 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1050, Reward Sum 3.0.
# [06-20 08:11:28 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1060, Reward Sum 3.0.
# [06-20 08:14:39 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1070, Reward Sum -3.0.
# [06-20 08:17:31 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1080, Reward Sum -1.0.
# [06-20 08:20:27 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1090, Reward Sum -6.0.
# [06-20 08:24:32 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1100, Test reward: -3.2
# [06-20 08:24:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1100, Reward Sum -8.0.
# [06-20 08:28:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1110, Reward Sum 6.0.
# [06-20 08:31:22 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1120, Reward Sum -1.0.
# [06-20 08:34:36 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1130, Reward Sum 13.0.
# [06-20 08:37:49 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1140, Reward Sum -2.0.
# [06-20 08:40:59 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1150, Reward Sum 2.0.
# [06-20 08:44:11 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1160, Reward Sum -2.0.
# [06-20 08:47:16 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1170, Reward Sum -3.0.
# [06-20 08:50:16 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1180, Reward Sum -5.0.
# [06-20 08:53:09 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1190, Reward Sum -3.0.
# [06-20 08:57:28 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1200, Test reward: 0.8
# [06-20 08:57:42 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1200, Reward Sum -12.0.
# [06-20 09:00:32 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1210, Reward Sum -4.0.
# [06-20 09:03:35 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1220, Reward Sum 3.0.
# [06-20 09:06:43 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1230, Reward Sum -11.0.
# [06-20 09:09:44 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1240, Reward Sum 1.0.
# [06-20 09:12:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1250, Reward Sum 1.0.
# [06-20 09:16:03 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1260, Reward Sum 3.0.
# [06-20 09:19:20 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1270, Reward Sum -6.0.
# [06-20 09:22:27 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1280, Reward Sum -1.0.
# [06-20 09:25:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1290, Reward Sum 2.0.
# [06-20 09:30:14 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1300, Test reward: -1.0
# [06-20 09:30:32 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1300, Reward Sum -3.0.
# [06-20 09:33:36 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1310, Reward Sum -3.0.
# [06-20 09:36:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1320, Reward Sum -13.0.
# [06-20 09:39:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1330, Reward Sum 1.0.
# [06-20 09:41:50 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1340, Reward Sum -5.0.
# [06-20 09:44:41 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1350, Reward Sum -8.0.
# [06-20 09:47:46 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1360, Reward Sum -4.0.
# [06-20 09:51:12 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1370, Reward Sum 3.0.
# [06-20 09:54:36 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1380, Reward Sum -1.0.
# [06-20 09:57:52 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1390, Reward Sum 1.0.
# [06-20 10:02:05 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1400, Test reward: -0.8
# [06-20 10:02:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1400, Reward Sum 4.0.
# [06-20 10:05:42 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1410, Reward Sum 5.0.
# [06-20 10:08:48 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1420, Reward Sum 6.0.
# [06-20 10:11:55 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1430, Reward Sum -1.0.
# [06-20 10:14:52 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1440, Reward Sum 5.0.
# [06-20 10:18:03 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1450, Reward Sum -2.0.
# [06-20 10:21:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1460, Reward Sum 3.0.
# [06-20 10:24:37 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1470, Reward Sum 6.0.
# [06-20 10:27:48 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1480, Reward Sum -10.0.
# [06-20 10:31:14 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1490, Reward Sum 2.0.
# [06-20 10:35:47 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1500, Test reward: -1.4
# [06-20 10:36:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1500, Reward Sum -2.0.
# [06-20 10:39:21 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1510, Reward Sum 5.0.
# [06-20 10:42:38 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1520, Reward Sum -4.0.
# [06-20 10:45:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1530, Reward Sum -6.0.
# [06-20 10:48:50 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1540, Reward Sum 6.0.
# [06-20 10:51:55 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1550, Reward Sum 4.0.
# [06-20 10:55:09 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1560, Reward Sum -3.0.
# [06-20 10:58:14 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1570, Reward Sum 7.0.
# [06-20 11:01:19 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1580, Reward Sum 3.0.
# [06-20 11:04:28 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1590, Reward Sum -1.0.
# [06-20 11:08:38 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1600, Test reward: 4.6
# [06-20 11:08:56 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1600, Reward Sum 2.0.
# [06-20 11:11:57 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1610, Reward Sum -1.0.
# [06-20 11:15:05 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1620, Reward Sum 5.0.
# [06-20 11:18:10 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1630, Reward Sum -8.0.
# [06-20 11:21:20 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1640, Reward Sum -2.0.
# [06-20 11:24:21 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1650, Reward Sum -3.0.
# [06-20 11:27:26 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1660, Reward Sum -5.0.
# [06-20 11:30:45 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1670, Reward Sum -3.0.
# [06-20 11:34:15 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1680, Reward Sum -1.0.
# [06-20 11:37:37 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1690, Reward Sum 3.0.
# [06-20 11:42:07 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1700, Test reward: -0.6
# [06-20 11:42:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1700, Reward Sum -7.0.
# [06-20 11:45:53 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1710, Reward Sum 3.0.
# [06-20 11:49:21 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1720, Reward Sum 1.0.
# [06-20 11:52:35 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1730, Reward Sum 2.0.
# [06-20 11:55:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1740, Reward Sum 9.0.
# [06-20 11:58:57 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1750, Reward Sum 2.0.
# [06-20 12:02:01 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1760, Reward Sum -8.0.
# [06-20 12:05:17 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1770, Reward Sum -5.0.
# [06-20 12:08:40 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1780, Reward Sum 5.0.
# [06-20 12:12:10 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1790, Reward Sum 1.0.
# [06-20 12:16:42 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1800, Test reward: -1.4
# [06-20 12:17:02 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1800, Reward Sum 2.0.
# [06-20 12:20:14 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1810, Reward Sum 4.0.
# [06-20 12:23:15 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1820, Reward Sum -2.0.
# [06-20 12:26:41 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1830, Reward Sum -5.0.
# [06-20 12:30:12 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1840, Reward Sum 5.0.
# [06-20 12:33:45 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1850, Reward Sum 3.0.
# [06-20 12:37:29 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1860, Reward Sum -7.0.
# [06-20 12:41:01 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1870, Reward Sum -2.0.
# [06-20 12:44:37 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1880, Reward Sum -3.0.
# [06-20 12:48:15 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1890, Reward Sum 2.0.
# [06-20 12:53:31 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 1900, Test reward: 2.4
# [06-20 12:53:52 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1900, Reward Sum 5.0.
# [06-20 12:57:43 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1910, Reward Sum -3.0.
# [06-20 13:01:39 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1920, Reward Sum 1.0.
# [06-20 13:05:15 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1930, Reward Sum -4.0.
# [06-20 13:08:33 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1940, Reward Sum -2.0.
# [06-20 13:12:00 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1950, Reward Sum -3.0.
# [06-20 13:15:29 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1960, Reward Sum 2.0.
# [06-20 13:18:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1970, Reward Sum -7.0.
# [06-20 13:22:13 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1980, Reward Sum -1.0.
# [06-20 13:25:46 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 1990, Reward Sum 3.0.
# [06-20 13:30:14 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2000, Test reward: 3.6
# [06-20 13:30:30 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2000, Reward Sum -6.0.
# [06-20 13:33:56 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2010, Reward Sum -7.0.
# [06-20 13:37:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2020, Reward Sum 2.0.
# [06-20 13:40:52 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2030, Reward Sum -9.0.
# [06-20 13:44:18 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2040, Reward Sum 9.0.
# [06-20 13:48:01 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2050, Reward Sum 3.0.
# [06-20 13:51:58 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2060, Reward Sum -1.0.
# [06-20 13:55:28 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2070, Reward Sum 1.0.
# [06-20 13:58:54 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2080, Reward Sum -3.0.
# [06-20 14:02:14 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2090, Reward Sum -9.0.
# [06-20 14:07:18 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2100, Test reward: 1.2
# [06-20 14:07:37 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2100, Reward Sum 8.0.
# [06-20 14:11:02 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2110, Reward Sum 6.0.
# [06-20 14:14:23 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2120, Reward Sum 4.0.
# [06-20 14:17:51 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2130, Reward Sum 6.0.
# [06-20 14:21:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2140, Reward Sum 7.0.
# [06-20 14:24:56 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2150, Reward Sum 6.0.
# [06-20 14:28:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2160, Reward Sum 3.0.
# [06-20 14:32:01 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2170, Reward Sum -1.0.
# [06-20 14:35:16 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2180, Reward Sum 7.0.
# [06-20 14:38:53 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2190, Reward Sum -2.0.
# [06-20 14:43:43 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2200, Test reward: -1.0
# [06-20 14:44:04 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2200, Reward Sum -1.0.
# [06-20 14:47:46 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2210, Reward Sum -4.0.
# [06-20 14:51:20 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2220, Reward Sum -8.0.
# [06-20 14:54:48 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2230, Reward Sum 4.0.
# [06-20 14:58:25 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2240, Reward Sum -7.0.
# [06-20 15:02:07 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2250, Reward Sum 9.0.
# [06-20 15:05:34 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2260, Reward Sum 9.0.
# [06-20 15:09:01 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2270, Reward Sum 7.0.
# [06-20 15:12:26 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2280, Reward Sum 3.0.
# [06-20 15:15:40 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2290, Reward Sum -3.0.
# [06-20 15:20:00 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2300, Test reward: 3.4
# [06-20 15:20:19 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2300, Reward Sum 7.0.
# [06-20 15:23:56 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2310, Reward Sum 3.0.
# [06-20 15:27:39 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2320, Reward Sum 11.0.
# [06-20 15:30:59 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2330, Reward Sum 3.0.
# [06-20 15:34:31 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2340, Reward Sum 6.0.
# [06-20 15:38:05 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2350, Reward Sum 4.0.
# [06-20 15:41:23 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2360, Reward Sum 5.0.
# [06-20 15:44:44 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2370, Reward Sum 6.0.
# [06-20 15:47:42 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2380, Reward Sum -1.0.
# [06-20 15:50:41 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2390, Reward Sum -4.0.
# [06-20 15:54:58 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2400, Test reward: 3.6
# [06-20 15:55:17 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2400, Reward Sum 1.0.
# [06-20 15:58:57 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2410, Reward Sum 4.0.
# [06-20 16:02:30 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2420, Reward Sum 4.0.
# [06-20 16:05:48 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2430, Reward Sum 1.0.
# [06-20 16:09:16 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2440, Reward Sum 1.0.
# [06-20 16:12:21 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2450, Reward Sum 5.0.
# [06-20 16:15:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2460, Reward Sum 3.0.
# [06-20 16:19:03 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2470, Reward Sum 5.0.
# [06-20 16:22:26 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2480, Reward Sum -4.0.
# [06-20 16:25:49 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2490, Reward Sum 3.0.
# [06-20 16:29:55 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2500, Test reward: -2.4
# [06-20 16:30:08 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2500, Reward Sum 9.0.
# [06-20 16:33:28 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2510, Reward Sum 1.0.
# [06-20 16:36:59 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2520, Reward Sum 1.0.
# [06-20 16:40:36 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2530, Reward Sum 9.0.
# [06-20 16:44:09 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2540, Reward Sum 12.0.
# [06-20 16:47:23 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2550, Reward Sum 6.0.
# [06-20 16:50:45 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2560, Reward Sum 3.0.
# [06-20 16:54:15 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2570, Reward Sum 3.0.
# [06-20 16:57:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2580, Reward Sum 1.0.
# [06-20 17:01:06 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2590, Reward Sum 1.0.
# [06-20 17:05:27 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2600, Test reward: 0.0
# [06-20 17:05:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2600, Reward Sum 2.0.
# [06-20 17:09:10 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2610, Reward Sum 1.0.
# [06-20 17:12:40 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2620, Reward Sum 1.0.
# [06-20 17:15:43 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2630, Reward Sum -3.0.
# [06-20 17:19:01 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2640, Reward Sum 9.0.
# [06-20 17:22:29 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2650, Reward Sum 2.0.
# [06-20 17:25:44 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2660, Reward Sum -2.0.
# [06-20 17:29:03 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2670, Reward Sum -1.0.
# [06-20 17:32:31 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2680, Reward Sum 4.0.
# [06-20 17:35:50 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2690, Reward Sum 7.0.
# [06-20 17:40:06 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2700, Test reward: 3.2
# [06-20 17:40:22 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2700, Reward Sum 9.0.
# [06-20 17:43:22 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2710, Reward Sum -1.0.
# [06-20 17:46:41 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2720, Reward Sum 6.0.
# [06-20 17:50:09 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2730, Reward Sum 5.0.
# [06-20 17:53:09 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2740, Reward Sum -4.0.
# [06-20 17:56:10 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2750, Reward Sum 4.0.
# [06-20 17:59:26 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2760, Reward Sum 1.0.
# [06-20 18:02:35 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2770, Reward Sum 8.0.
# [06-20 18:06:08 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2780, Reward Sum 4.0.
# [06-20 18:09:20 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2790, Reward Sum 7.0.
# [06-20 18:13:50 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2800, Test reward: 0.0
# [06-20 18:14:09 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2800, Reward Sum -1.0.
# [06-20 18:17:20 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2810, Reward Sum -7.0.
# [06-20 18:20:46 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2820, Reward Sum -1.0.
# [06-20 18:23:47 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2830, Reward Sum 5.0.
# [06-20 18:27:08 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2840, Reward Sum -1.0.
# [06-20 18:30:35 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2850, Reward Sum 1.0.
# [06-20 18:33:45 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2860, Reward Sum 8.0.
# [06-20 18:37:11 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2870, Reward Sum -6.0.
# [06-20 18:40:43 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2880, Reward Sum -1.0.
# [06-20 18:44:02 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2890, Reward Sum -6.0.
# [06-20 18:48:33 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 2900, Test reward: 2.6
# [06-20 18:48:54 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2900, Reward Sum 1.0.
# [06-20 18:52:16 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2910, Reward Sum 1.0.
# [06-20 18:55:24 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2920, Reward Sum -2.0.
# [06-20 18:58:41 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2930, Reward Sum 4.0.
# [06-20 19:02:00 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2940, Reward Sum -3.0.
# [06-20 19:05:05 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2950, Reward Sum 10.0.
# [06-20 19:08:19 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2960, Reward Sum -1.0.
# [06-20 19:11:14 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2970, Reward Sum -2.0.
# [06-20 19:14:16 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2980, Reward Sum 3.0.
# [06-20 19:17:41 MainThread @<ipython-input-8-69d5f0d42f1c>:52] Train Episode 2990, Reward Sum -1.0.
# [06-20 19:22:04 MainThread @<ipython-input-8-69d5f0d42f1c>:62] Episode 3000, Test reward: 4.4
